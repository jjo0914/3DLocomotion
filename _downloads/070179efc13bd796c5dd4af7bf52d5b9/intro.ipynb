# %% [markdown]
# <a href="https://colab.research.google.com/github/jjo0914/3DLocomotion/blob/main/_downloads/070179efc13bd796c5dd4af7bf52d5b9/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For tips on running notebooks in Google Colab, see
# https://docs.pytorch.org/tutorials/beginner/colab
# %matplotlib inline
from google.colab import drive  # google.colab.drive를 drive.으로 사
drive.mount('/content/drive') # 경로고정/ 이후에는 /content/drive/MyDrive/ drive 내에 경로지정
# path :/content/drive/MyDrive/)
# !pip install bvh
from bvh import Bvh # bvh. 를 Bvh로사용가능
path="/content/drive/MyDrive/dataset-2_run_normal_001.bvh"

with open(path,"r") as f: # with 문법 열고 자동닫기 or 끄고 다시켜기 등등
  data=Bvh(f.read()) # f.read로 전체문자열을 가져오고 bvh가 자동으로 파싱해준다
print("프레임 수:", data.nframes)
print("프레임 시간:", data.frame_time)
print("관절 이름:", data.get_joints_names())
print("UpperLeg_L offset :",data.joint_offset("UpperLeg_L"))
print("LowerLeg_L offset :",data.joint_offset("LowerLeg_L"))
print("Foot_L offset :",data.joint_offset("Foot_L"))
print("Toes_L offset :",data.joint_offset("Toes_L"))
print("UpperLeg_R offset :",data.joint_offset("UpperLeg_R"))
print("LowerLeg_R offset :",data.joint_offset("LowerLeg_R"))
print("Foot_R offset :",data.joint_offset("Foot_R"))
print("Toes_R offset :",data.joint_offset("Toes_R"))

print("Hipes offset :",data.joint_offset("Hips"))

##
all_frame=68;
joint_name = "Toes_R"
channel1="Xrotation"
channel2="Yrotation"
channel3="Zrotation"
channel4="Xposition"
channel5="Yposition"
channel6="Zposition"


frame_idx = list(range(0,all_frame)) # 프레임 갯수
Xrotation=[];
Yrotation=[];
Zrotation=[];
Xposition=[]
Yposition=[]
Zposition=[]

for frame in frame_idx:
    x = data.frame_joint_channel(frame, joint_name, channel1)
    y = data.frame_joint_channel(frame, joint_name, channel2)
    z = data.frame_joint_channel(frame, joint_name, channel3)
    xp=data.frame_joint_channel(frame, joint_name, channel4)
    yp=data.frame_joint_channel(frame, joint_name, channel5)
    zp=data.frame_joint_channel(frame, joint_name, channel6)
    Xrotation.append(x)
    Yrotation.append(y)
    Zrotation.append(z)
    Xposition.append(xp)
    Yposition.append(yp)
    Zposition.append(zp)
print(joint_name, channel1)
print(Xrotation)
print(joint_name, channel2)
print(Yrotation)
print(joint_name, channel3)
print(Zrotation)
print(joint_name, channel4)
print(Xposition)
print(joint_name, channel5)
print(Yposition)
print(joint_name, channel6)
print(Zposition)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: bvh in /usr/local/lib/python3.12/dist-packages (0.3)
# 프레임 수: 68
# 프레임 시간: 0.0333333
# 관절 이름: ['joint_Root', 'Hips', 'Spine', 'Chest', 'Neck', 'Head', 'Shoulder_L', 'UpperArm_L', 'LowerArm_L', 'Hand_L', 'Shoulder_R', 'UpperArm_R', 'LowerArm_R', 'Hand_R', 'UpperLeg_L', 'LowerLeg_L', 'Foot_L', 'Toes_L', 'UpperLeg_R', 'LowerLeg_R', 'Foot_R', 'Toes_R']
# UpperLeg_L offset : (-2.19248, -6.46944, 0.0)
# LowerLeg_L offset : (39.0811, 0.0, -1.23785e-05)
# Foot_L offset : (40.9854, 0.0, -1.26872e-05)
# Toes_L offset : (11.7543, 0.0, 0.0)
# UpperLeg_R offset : (-2.19251, 6.46944, 0.0)
# LowerLeg_R offset : (-39.0811, -0.00228153, -0.0401928)
# Foot_R offset : (-40.9854, 0.0, 0.0)
# Toes_R offset : (-11.7543, 0.0, 0.0)
# Hipes offset : (-0.726466, 93.3139, -2.00062)
# Toes_R Xrotation
# [-0.163173, -0.150411, -0.140492, -0.156501, -0.15907, -0.168443, -0.174092, -0.174699, -0.170291, -0.172518, -0.107728, -0.100201, -0.122371, -0.242734, -0.634286, -0.763796, -0.147254, -0.162781, -0.157986, -0.164575, -0.177386, -0.176432, -0.169919, -0.154358, -0.162793, -0.149269, -0.158305, -0.161227, -0.168634, -0.17032, -0.17351, -0.187942, -0.064495, -0.144864, -1.27293, -0.396856, -0.780924, -0.154316, -0.158802, -0.153577, -0.152385, -0.152154, -0.160652, -0.167035, -0.166319, -0.163595, -0.164806, -0.150066, -0.156941, -0.160487, -0.158221, -0.180664, -0.18974, -0.269283, -0.058091, -0.174049, -2.19837, -0.314224, -0.694714, -0.47602, -0.168037, -0.170765, -0.168398, -0.16168, -0.157149, -0.156877, -0.152829, -0.143905]
# Toes_R Yrotation
# [-23.2384, -22.7133, -22.3058, -22.9638, -23.0695, -23.4554, -23.6882, -23.7133, -23.5316, -23.6234, -20.9629, -20.6551, -21.5626, -26.5328, -43.7117, -50.0263, -22.5836, -23.2222, -23.0249, -23.2961, -23.8241, -23.7847, -23.5162, -22.8756, -23.2227, -22.6664, -23.038, -23.1582, -23.4633, -23.5327, -23.6642, -24.2598, -19.1975, -18.9211, -21.7944, -33.0569, -50.8992, -22.8739, -23.0585, -22.8435, -22.7945, -22.785, -23.1346, -23.3974, -23.3679, -23.2557, -23.3056, -22.6991, -22.9819, -23.1278, -23.0345, -23.9593, -24.3341, -27.6416, -18.9365, -17.7313, -21.0607, -29.5315, -46.6005, -36.5094, -23.4387, -23.5511, -23.4536, -23.1769, -22.9904, -22.9793, -22.8127, -22.446]
# Toes_R Zrotation
# [-0.019263, -0.017058, -0.015427, -0.018095, -0.018541, -0.020209, -0.021246, -0.021358, -0.020545, -0.020954, -0.010553, -0.009544, -0.012635, -0.035757, -0.193553, -0.279917, -0.016531, -0.019194, -0.018352, -0.019513, -0.021861, -0.021682, -0.020477, -0.017727, -0.019196, -0.016867, -0.018408, -0.018919, -0.020244, -0.020551, -0.021138, -0.023888, -0.005316, -0.082762, -1.11942, -0.081767, -0.292961, -0.01772, -0.018494, -0.017594, -0.017391, -0.017352, -0.018818, -0.019954, -0.019825, -0.019338, -0.019554, -0.017, -0.018171, -0.018789, -0.018393, -0.022481, -0.024241, -0.042334, -0.004655, -0.126969, -1.93167, -0.054724, -0.23129, -0.113126, -0.020135, -0.020632, -0.020201, -0.018999, -0.018207, -0.01816, -0.017467, -0.01598]
# Toes_R Xposition
# [-11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543, -11.7543]
# Toes_R Yposition
# [-6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06]
# Toes_R Zposition
# [-6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06, -6e-06]

# %% [markdown]
# **Learn the Basics** \|\| [Quickstart](quickstart_tutorial.html) \|\|
# [Tensors](tensorqs_tutorial.html) \|\| [Datasets &
# DataLoaders](data_tutorial.html) \|\|
# [Transforms](transforms_tutorial.html) \|\| [Build
# Model](buildmodel_tutorial.html) \|\|
# [Autograd](autogradqs_tutorial.html) \|\|
# [Optimization](optimization_tutorial.html) \|\| [Save & Load
# Model](saveloadrun_tutorial.html)
#
# Learn the Basics
# ================
#
# Authors: [Suraj Subramanian](https://github.com/subramen), [Seth
# Juarez](https://github.com/sethjuarez/), [Cassie
# Breviu](https://github.com/cassiebreviu/), [Dmitry
# Soshnikov](https://soshnikov.com/), [Ari
# Bornstein](https://github.com/aribornstein/)
#
# Most machine learning workflows involve working with data, creating
# models, optimizing model parameters, and saving the trained models. This
# tutorial introduces you to a complete ML workflow implemented in
# PyTorch, with links to learn more about each of these concepts.
#
# We\'ll use the FashionMNIST dataset to train a neural network that
# predicts if an input image belongs to one of the following classes:
# T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker,
# Bag, or Ankle boot.
#
# [This tutorial assumes a basic familiarity with Python and Deep Learning
# concepts.]{.title-ref}
#
# Running the Tutorial Code
# -------------------------
#
# You can run this tutorial in a couple of ways:
#
# -   **In the cloud**: This is the easiest way to get started! Each
#     section has a \"Run in Google Colab\" link at the top, which opens
#     an integrated notebook in Google Colab with the code in a
#     fully-hosted environment.
# -   **Locally**: This option requires you to set up PyTorch and
#     TorchVision first on your local machine ([installation
#     instructions](https://pytorch.org/get-started/locally/)). Download
#     the notebook or copy the code into your favorite IDE.
#
# How to Use this Guide
# ---------------------
#
# If you\'re familiar with other deep learning frameworks, check out the
# [0. Quickstart](quickstart_tutorial.html) first to quickly familiarize
# yourself with PyTorch\'s API.
#
# If you\'re new to deep learning frameworks, head right into the first
# section of our step-by-step guide: [1. Tensors](tensorqs_tutorial.html).
#
# ::: {.toctree maxdepth="2" hidden=""}
# quickstart\_tutorial tensorqs\_tutorial data\_tutorial
# transforms\_tutorial buildmodel\_tutorial autogradqs\_tutorial
# optimization\_tutorial saveloadrun\_tutorial
# :::
